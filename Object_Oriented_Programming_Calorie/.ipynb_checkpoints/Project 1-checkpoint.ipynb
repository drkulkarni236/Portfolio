# %%
# Defining classes and functions

class survey:
    
    user_count = 0
    user_list = []
    
    def __init__(self):
        self.questions = []
        self.options = []
        self.fun_facts = []
        self.question_number = 0
        self.dict = {}
        self.dict['user'] = user()
            
    def welcome(self):
        '''This function prints a welcome message for the user'''
        
        print('Welcome to Be Well, a health survey.')
        print('This survey will ask you a series of questions about your physical and mental health')
        print('and provides you with recommendations on what you can do to improve your health')
        print('')
        
    
    def get_questions(self):
        '''This function accesses the questions.txt file and gets a list of questions to ask'''
        
        with open('questions.txt') as f:
            self.questions = f.read().splitlines()
            
    
    def get_options(self):
        '''This function accesses the options.txt file and gets a list of options corresponding 
        to the questions'''
        
        with open('options.txt') as f:
            self.options = f.read().splitlines()
            
    
    def get_fun_facts(self):
        '''This function accesses the funfacts.txt file and gets a list of fun facts corresponding 
        to the questions'''
        
        with open('options.txt') as f:
            self.fun_facts = f.read().splitlines()
            
    
    def ask_question(self, question_number):
        '''This function prints out the question to the user interface based on the question number'''
        
        print(self.questions[question_number])
        print('')
        
    
    def provide_option(self, question_number):
        '''This function prints out the options to the user interface based on the question number'''
        
        if self.options[question_number]:
            print(self.options[question_number])
            print('')
            
    
    def receive_answer(self, question_number):
        '''This function receives the answers to a particular question from the user 
        based on the question number'''
        
        self.ans = input('Ans: ')
        
        if question_number == 0:
            self.dict['user'].set_name(self.ans)
            print(question_number)
        elif question_number == 1:
            self.dict['user'].set_name(self.ans)
            print(question_number)
        elif question_number == 2:
            self.dict['user'].set_name(self.ans)
            print(question_number)
        elif question_number == 3:
            self.dict['user'].set_name(self.ans)
            print(question_number)
        elif question_number == 4:
            self.dict['user'].set_name(self.ans)
            print(question_number)

        
class user:
    
    def __init__(self):
        '''This function will initialize a user object with the requried attributes'''
        
    
    def get_name(self):
            return self.__name
        
    def set_name(self, name):
        self.__name = name
            
    def get_age(self):
            return self.__age
        
    def set_age(self, age):
        if age < 18 or age > 60:
            raise AgeError
        else:
            self.__age = age
            
    def get_sex(self):
            return self.__sex
        
    def set_sex(self, name):
            self.__sex = sex
        
    def calculate_resting_cal(self):
        '''This method calculates resting calorie count for a person 
        based on their sex, age, height and weight'''
        
        if self.sex == 'male':
            user.resting_cal_count = 65 + (6.2 * self.weight) * (12.7 * self.height) - (6.8 * self.age)
        
        elif self.sex == 'female':
            user.resting_cal_count = 655 + (4.3 * self.weight) + (4.3 * self.height) - (4.7 * self.age)
            
        
class nutrition:
    pass

class physiology:
    pass

class wellbeing:
    pass

class scores:
    pass

class AgeError(Error):
    '''Raised when age is not in the range of 18 to 60'''
    pass

# %%
S = survey()
S.welcome()
S.get_questions()
S.get_options()

for i in range(1):
    S.ask_question(i)
    S.provide_option(i)
    S.receive_answer(i)
# Out:
# Welcome to Be Well, a health survey.
# This survey will ask you a series of questions about your physical and mental health
# and provides you with recommendations on what you can do to improve your health
#
# 1) Please enter your name:
#
# Ans: D
# inisde user.set_name
# 0

# %%
S.dict['user'].get_name()
# Out:
# 'D'
